# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import seaborn as sns

# %%
#esto es para forzar a plt a poner fondos blancos en las figuras aunque el tema del notebook sea oscuro
#plt.rcParams['axes.facecolor'] = 'white'
#plt.rcParams['figure.facecolor'] = 'white'
cmap = plt.get_cmap("tab10")
pio.templates.default = "seaborn"

sns.set_style("darkgrid", rc={'xtick.bottom': True})

# %%
data_processed = "../../../data/processed/"
graph_data = data_processed + "graph_data_nohubs/"
reports = "../../../reports/reports_nohubs/"
reports_lsa = "../../../reports/reports_nohubs/analisis_lsa/"

infomap_meansim = pd.read_csv(reports_lsa+"infomap_meansim.csv")
infomap_pvalues = pd.read_csv(reports_lsa+"infomap_random_pvalues.csv")

louvain_meansim = pd.read_csv(reports_lsa+"louvain_meansim.csv")
louvain_pvalues = pd.read_csv(reports_lsa+"louvain_random_pvalues.csv")

infomap_summary = pd.read_pickle(reports+"infomap_summary.pkl")
louvain_summary = pd.read_pickle(reports+"louvain_summary.pkl")

# %%
case_dict = {0:"monogramas",1:"bigramas",2:"trigramas",3:"mixto"}

for i in range(4):
    fig, ax = plt.subplots(1,2,figsize=(18,6))
    fig.suptitle(f"Similaridad media entre nodos de clusters - {case_dict[i]}")
    # ticks = np.logspace(0,tamaños_infomap.max(),10)

    sns.histplot(data=infomap_meansim[f"mean_sim_lsa_{i}"], ax=ax[0], bins=np.linspace(0,1,20))
    ax[0].set_xlabel("Similaridad media")
    ax[0].set_title("Infomap")

    sns.histplot(data=louvain_meansim[f"mean_sim_lsa_{i}"], ax=ax[1],bins=np.linspace(0,1,20))
    ax[1].set_xlabel("Similaridad media")
    ax[1].set_title("Louvain")

# %% [markdown]
# # Corrección FDR

# %%
from statsmodels.stats import multitest

# %%
infomap_pvalues_reject = infomap_pvalues.set_index("comunidad").apply(lambda x: multitest.fdrcorrection(x)[0])
louvain_pvalues_reject = louvain_pvalues.set_index("comunidad").apply(lambda x: multitest.fdrcorrection(x)[0])

infomap_pvalues_adjusted = infomap_pvalues.set_index("comunidad").apply(lambda x: multitest.fdrcorrection(x)[1])
louvain_pvalues_adjusted = louvain_pvalues.set_index("comunidad").apply(lambda x: multitest.fdrcorrection(x)[1])

# %%
infomap_pvalues_reject.pvalue_0.value_counts()
# Out:
# True     1134
# False      14
# Name: pvalue_0, dtype: int64

# %%
plot = plt.hist(infomap_pvalues_adjusted.pvalue_0, log=True)

# %%
(9*100)/294
# Out:
# 3.061224489795918

# %%
louvain_pvalues_reject.pvalue_0.value_counts()
# Out:
# True     285
# False      9
# Name: pvalue_0, dtype: int64

# %%
plot = plt.hist(louvain_pvalues_adjusted.pvalue_0,log=True)

# %%
infomap_rejected = infomap_summary.set_index("comunidad").loc[infomap_pvalues_reject[infomap_pvalues_reject.pvalue_0 == False].index.values].reset_index()
cols = ["comunidad","tamaño","mean_sim_lsa_0","top_monogram","top_5_monogram","top_5_monogram_score","entropia_0"]
infomap_rejected[cols]
# Out:
#     comunidad  tamaño  mean_sim_lsa_0    top_monogram  \
# 0         769       6            0.01      primordial
# 1         196       5            0.08       exostosis
# 2        1114       4            0.00    malformation
# 3         356       4            0.00          cornea
# 4         876       3            0.00       palpebral
# 5         730       3            0.04          matter
# 6        1038       3            0.10          glomus
# 7        1030       3            0.00            void
# 8        1104       3            0.00         histone
# 9        1118       2            0.08         removal
# 10       1000       2            0.03  schizencephaly
# 11       1133       2            0.00            bone
# 12       1136       2            0.03           class
# 13       1137       2            0.01          atonic
#
#                                        top_5_monogram  \
# 0    [primordial, length, restriction, birth, growth]
# 1   [exostosis, epiphysis, cone, multiple, redundant]
# 2    [malformation, limb, eastern, descent, skeleton]
# 3    [cornea, keratoconus, protrusion, corneal, cone]
# 4           [palpebral, fissure, long, eyebrow, arch]
# 5   [matter, white, mri, leukoencephalopathy, cavi...
# 6              [glomus, tumor, cluster, vein, dilate]
# 7   [void, expression, facial, dysfunction, aquedu...
# 8   [histone, deletion, 9q34, methyltransferase, l...
# 9   [removal, dissolution, osteolysis, bone, calcium]
# 10  [schizencephaly, cleft, hemisphere, grey, cere...
# 11    [bone, hyperostosis, ced, fatigability, waddle]
# 12  [class, expression, immunodeficiency, hla, pic...
# 13       [atonic, innervate, congenita, tone, spinal]
#
#               top_5_monogram_score  entropia_0
# 0      [0.39, 0.3, 0.3, 0.3, 0.28]        0.33
# 1    [0.57, 0.32, 0.3, 0.23, 0.21]        0.42
# 2     [0.31, 0.3, 0.3, 0.27, 0.27]        0.35
# 3    [0.59, 0.35, 0.3, 0.27, 0.25]        0.44
# 4   [0.25, 0.23, 0.23, 0.19, 0.18]        0.49
# 5    [0.4, 0.26, 0.25, 0.22, 0.19]        0.43
# 6    [0.86, 0.21, 0.2, 0.18, 0.17]        0.26
# 7   [0.46, 0.39, 0.29, 0.28, 0.23]        0.34
# 8   [0.43, 0.29, 0.29, 0.28, 0.25]        0.42
# 9    [0.41, 0.4, 0.38, 0.37, 0.36]        0.34
# 10  [0.53, 0.28, 0.28, 0.24, 0.24]        0.42
# 11   [0.34, 0.34, 0.3, 0.26, 0.24]        0.39
# 12   [0.44, 0.37, 0.33, 0.23, 0.2]        0.42
# 13   [0.71, 0.31, 0.28, 0.25, 0.2]        0.27

# %%
louvain_rejected = louvain_summary.set_index("comunidad").loc[louvain_pvalues_reject[louvain_pvalues_reject.pvalue_0 == False].index.values].reset_index()
cols = ["comunidad","tamaño","mean_sim_lsa_0","top_monogram","top_5_monogram","top_5_monogram_score","entropia_0"]
louvain_rejected[cols]
# Out:
#    comunidad  tamaño  mean_sim_lsa_0    top_monogram  \
# 0        260       4            0.00            limb
# 1        250       3            0.00         histone
# 2         99       3            0.00       palpebral
# 3        182       3            0.00            void
# 4        279       2            0.00            bone
# 5        282       2            0.03           class
# 6        283       2            0.01          atonic
# 7        156       2            0.03  schizencephaly
# 8        264       2            0.08            bone
#
#                                       top_5_monogram  \
# 0   [limb, malformation, eastern, skeleton, descent]
# 1  [histone, 9q34, methyltransferase, deletion, l...
# 2      [palpebral, long, fissure, eyebrow, eversion]
# 3  [void, expression, dysfunction, facial, aquedu...
# 4            [bone, hyperostosis, ced, long, waddle]
# 5  [class, expression, immunodeficiency, infectio...
# 6       [atonic, innervate, congenita, tone, spinal]
# 7  [schizencephaly, cleft, hemisphere, cerebral, ...
# 8  [bone, removal, dissolution, osteolysis, calcium]
#
#              top_5_monogram_score  entropia_0
# 0  [0.32, 0.32, 0.31, 0.26, 0.26]        0.34
# 1  [0.42, 0.29, 0.27, 0.27, 0.25]        0.42
# 2  [0.26, 0.25, 0.23, 0.19, 0.18]        0.49
# 3  [0.45, 0.37, 0.31, 0.29, 0.22]        0.34
# 4  [0.39, 0.32, 0.29, 0.24, 0.24]        0.38
# 5  [0.41, 0.36, 0.32, 0.23, 0.22]        0.42
# 6   [0.7, 0.31, 0.28, 0.24, 0.21]        0.26
# 7  [0.54, 0.29, 0.27, 0.25, 0.24]        0.41
# 8  [0.42, 0.39, 0.39, 0.37, 0.36]        0.34
