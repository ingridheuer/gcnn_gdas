# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import seaborn as sns

# %%
#esto es para forzar a plt a poner fondos blancos en las figuras aunque el tema del notebook sea oscuro
#plt.rcParams['axes.facecolor'] = 'white'
#plt.rcParams['figure.facecolor'] = 'white'
cmap = plt.get_cmap("tab10")
pio.templates.default = "seaborn"

sns.set_style("darkgrid", rc={'xtick.bottom': True})

# %%
data_processed = "../../../data/processed/"
graph_data = data_processed + "graph_data_nohubs/"
reports = "../../../reports/reports_nohubs/"
reports_lsa = "../../../reports/reports_nohubs/analisis_lsa/"

infomap_summary = pd.read_pickle(reports+"infomap_summary.pkl")
louvain_summary = pd.read_pickle(reports+"louvain_summary.pkl")

# %%
infomap_summary.columns
# Out:
# Index(['comunidad', 'tamaño', 'mean_sim_lsa_0', 'mean_sim_lsa_1',
#        'mean_sim_lsa_2', 'mean_sim_lsa_3', 'entropia_0', 'entropia_1',
#        'entropia_2', 'entropia_3', 'top_monogram', 'top_monogram_score',
#        'top_5_monogram', 'top_5_monogram_score', 'top_bigram',
#        'top_bigram_score', 'top_5_bigram', 'top_5_bigram_score', 'top_trigram',
#        'top_trigram_score', 'top_5_trigram', 'top_5_trigram_score',
#        'top_mixed', 'top_mixed_score', 'top_5_mixed', 'top_5_mixed_score'],
#       dtype='object')

# %%
ngram_dict = {0:"monogramas",1:"bigramas",2:"trigramas",3:"mixto"}

def supergrafico(df,i,titulo):
    entropy_col = f"entropia_{i}"
    meansim_col = f"mean_sim_lsa_{i}"
    x = 1-df[entropy_col] 
    fig = px.scatter(df, x=x, y=meansim_col, size="tamaño",width=1000, height=600, title=f"Especificidad vs similaridad media vs tamaño - {titulo}",marginal_x="histogram",marginal_y="histogram",range_x=[0,1],range_y=[0,1])
    fig.update_layout(xaxis_title="Spec", yaxis_title=f"Similaridad media - {ngram_dict[i]}")

    fig.show()

# %%
supergrafico(infomap_summary,0,"Infomap")

# %%
supergrafico(louvain_summary,0,"Louvain")
